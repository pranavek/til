# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 

x = np.random.randn(1000)
plt.hist(x,100)
plt.title('Pranav\'s Histogram')
plt.show()

# %%
plt.plot(5,5,'o')
plt.show()

# %%
imm_canada = {'india':[5704,7338,8147,8670,8880],'china':[1527,1863,3308,6682,5213]}
year = [1984,1983,1982,1981,1980]
df = pd.DataFrame(imm_canada,index=year)
df.plot(kind='line')
